# %%
# !pip install ipython-sql
# %load_ext sql
# %sql sqlite:///university.db
# Out:
# Requirement already satisfied: ipython-sql in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: prettytable<1 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: ipython>=1.0 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython-sql) (7.26.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython-sql) (1.4.23)
# Requirement already satisfied: sqlparse in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython-sql) (0.4.1)
# Requirement already satisfied: six in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (68.2.2)
# Requirement already satisfied: jedi>=0.16 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.18.0)
# Requirement already satisfied: decorator in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (5.0.9)
# Requirement already satisfied: pickleshare in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (5.9.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (3.0.19)
# Requirement already satisfied: pygments in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (2.10.0)
# Requirement already satisfied: backcall in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: pexpect>4.3 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /home/soumik/miniconda3/envs/jupyter/lib/python3.10/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS students (
#     inter_dom TEXT,
#     region TEXT,
#     gender TEXT,
#     academic TEXT,
#     age INTEGER,
#     age_cate INTEGER,
#     stay INTEGER,
#     stay_cate TEXT,
#     japanese INTEGER,
#     japanese_cate TEXT,
#     english INTEGER,
#     english_cate TEXT,
#     intimate TEXT,
#     religion TEXT,
#     suicide TEXT,
#     dep TEXT,
#     deptype TEXT,
#     todep INTEGER,
#     depsev TEXT,
#     tosc INTEGER,
#     apd INTEGER,
#     ahome INTEGER,
#     aph INTEGER,
#     afear INTEGER,
#     acs INTEGER,
#     aguilt INTEGER,
#     amiscell INTEGER,
#     toas INTEGER,
#     partner INTEGER,
#     friends INTEGER,
#     parents INTEGER,
#     relative INTEGER,
#     profess INTEGER,
#     phone INTEGER,
#     doctor INTEGER,
#     reli INTEGER,
#     alone INTEGER,
#     others INTEGER,
#     internet INTEGER,
#     partner_bi TEXT,
#     friends_bi TEXT,
#     parents_bi TEXT,
#     relative_bi TEXT,
#     professional_bi TEXT,
#     phone_bi TEXT,
#     doctor_bi TEXT,
#     religion_bi TEXT,
#     alone_bi TEXT,
#     others_bi TEXT,
#     internet_bi TEXT
# );
# Out:
#  * sqlite:///university.db
# Done.
# []

# %%
import pandas as pd
import sqlite3

conn = sqlite3.connect("university.db")
df = pd.read_csv("data/students.csv")
df.to_sql("students", con=conn, if_exists="replace", index=False)
# Out:
# 268
